# %% [markdown]
# Connected to Python 3.11.4

# %%
# import libraries

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/loan_data_2007_2014.csv')
df.head()
# Out:
# /var/folders/m7/tg2l9_wd0ln9hyzshb_vzvpwhz9w_d/T/ipykernel_1068/727553800.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/loan_data_2007_2014.csv')
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
# 3           3  1076863    1277178      10000        10000          10000.0
# 4           4  1075358    1311748       3000         3000           3000.0
#
#          term  int_rate  installment grade sub_grade  \
# 0   36 months     10.65       162.87     B        B2
# 1   60 months     15.27        59.83     C        C4
# 2   36 months     15.96        84.33     C        C5
# 3   36 months     13.49       339.31     C        C1
# ...

# %%
# general preprosessing
df_backup = df.copy()

pd.options.display.max_columns = None
df.head(3)
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599       5000         5000           4975.0
# 1           1  1077430    1314167       2500         2500           2500.0
# 2           2  1077175    1313524       2400         2400           2400.0
#
#          term  int_rate  installment grade sub_grade emp_title emp_length  \
# 0   36 months     10.65       162.87     B        B2       NaN  10+ years
# 1   60 months     15.27        59.83     C        C4     Ryder   < 1 year
# 2   36 months     15.96        84.33     C        C5       NaN  10+ years
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT     24000.0            Verified  Dec-11   Fully Paid
# 1           RENT     30000.0     Source Verified  Dec-11  Charged Off
# 2           RENT     12252.0        Not Verified  Dec-11   Fully Paid
#
#   pymnt_plan                                                url  \
# ...

# %%
numerical = ["loan_amnt", "funded_amnt", 
             "funded_amnt_inv", "int_rate",
             "installment", "annual_inc", 
             "inq_last_6mths", "delinq_2yrs",
             "open_acc", "revol_bal",
             "revol_util", "total_acc",
             "pub_rec", "out_prncp",
             "out_prncp_inv", "total_pymnt",
             "total_pymnt_inv", "total_rec_prncp",
             "total_rec_int", "total_rec_late_fee",
             "collections_12_mths_ex_med", "mths_since_last_major_derog",
             "policy_code", "annual_inc_joint",
             "dti_joint",  "tot_cur_bal",
             "acc_now_delinq"
             ]

categorical = ["term", "emp_title",
                "emp_length", "home_ownership", 
                "verification_status", "issue_d", 
                "purpose", "title",
                "initial_list_status",  "application_type"]
geo_hard = ["zip_code", "addr_state"]

time_ = ["earliest_cr_line", "last_pymnt_d", "last_credit_pull_d"]

not_useful = ["url", "desc"]

may_be_likeages = ["grade", "sub_grade",
                   "pymnt_plan","recoveries", 
                   "collection_recovery_fee"
                  ]
target = ["loan_status"]

# %%
PD_dict = {"target": target, 
           "numerical": numerical, 
           "categorical": categorical, 
           "geo_hard": geo_hard, "time_": time_,
           "may_be_likeages": may_be_likeages}

# %% [markdown]
# ## basic cleaning

# %%
from utils import clear_columns_with_95_percent_of_nan
# lets start only with numerical and categorical
numerical_ = clear_columns_with_95_percent_of_nan(df_backup, numerical)
categorical_ = clear_columns_with_95_percent_of_nan(df_backup, categorical)

# %%
# lets remove the columns that have only one unique value
from utils import  clear_not_varying_cols


numerical_1 = clear_not_varying_cols(df_backup[numerical_], numerical_).columns.tolist()
categorical_1 = clear_not_varying_cols(df_backup[categorical_], categorical_).columns.tolist()

# %%
# some exploratory analysis
import matplotlib.pyplot as plt
import seaborn as sns

# lets see the distribution of the target
df_backup[target].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='loan_status'>

# %%
# shot a column ad the percentage of each of the values as well
df_backup[target].value_counts( normalize=True)
# Out:
# loan_status
# Current                                                0.480878
# Fully Paid                                             0.396193
# Charged Off                                            0.091092
# Late (31-120 days)                                     0.014798
# In Grace Period                                        0.006747
# Does not meet the credit policy. Status:Fully Paid     0.004263
# Late (16-30 days)                                      0.002612
# Default                                                0.001784
# Does not meet the credit policy. Status:Charged Off    0.001632
# Name: proportion, dtype: float64
